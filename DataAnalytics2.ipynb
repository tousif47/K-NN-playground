# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as pyplot
import pandas as pd
import json
from datetime import datetime
from datetime import time

pyplot.rcParams["figure.figsize"] = (10, 5)

# %%
with open("flow_rates.json", "r") as f:
    data = json.load(f)

# Length of data
len(data)
# Out:
# 31543791

# %%
temp = list()
for i in range(len(data)):
    if (data[i]['value'] != 0):
        data[i]['timestamp'] = datetime.fromtimestamp(data[i]['ts'])
        data[i]['time'] = data[i]['timestamp'].time()
        temp.append(data[i])

data = temp

# %%
print(len(data))
data.sort(key=lambda x:x['timestamp'])
data[0:5]
# Out:
# 295350
# [{'serial_no': '0027AFA4',
#   'ts': 1579505323,
#   'value': 472,
#   'timestamp': datetime.datetime(2020, 1, 20, 15, 28, 43),
#   'time': datetime.time(15, 28, 43)},
#  {'serial_no': '0027AFA4',
#   'ts': 1579505324,
#   'value': 475,
#   'timestamp': datetime.datetime(2020, 1, 20, 15, 28, 44),
#   'time': datetime.time(15, 28, 44)},
#  {'serial_no': '0027AFA4',
#   'ts': 1579505325,
#   'value': 474,
#   'timestamp': datetime.datetime(2020, 1, 20, 15, 28, 45),
#   'time': datetime.time(15, 28, 45)},
#  {'serial_no': '0027AFA4',
#   'ts': 1579505326,
#   'value': 461,
#   'timestamp': datetime.datetime(2020, 1, 20, 15, 28, 46),
#   'time': datetime.time(15, 28, 46)},
#  {'serial_no': '0027AFA4',
#   'ts': 1579505327,
#   'value': 469,
#   'timestamp': datetime.datetime(2020, 1, 20, 15, 28, 47),
#   'time': datetime.time(15, 28, 47)}]

# %%
df = pd.DataFrame(data[450:600])
pyplot.figure()
pyplot.plot(df['timestamp'], df['value'])
pyplot.xlabel('Time')
pyplot.ylabel('Flow')
pyplot.suptitle("Test")
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
datetime.fromtimestamp(data[1000]['ts']).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-04-17 18:29:07'
